# %% [markdown]
# #### Introduction -- In this project, we will analyze the California housing dataset, a valuable resource for exploring the real estate market in California, USA.The dataset provides comprehensive information about various housing properties across different regions in California.Our objective is to gain insights into the factors that influence housing prices and create a predictive model to estimate the median house value.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data=pd.read_excel('housing.xlsx')

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2         496         177         7.2574              352100        NEAR BAY
# 3         558         219         5.6431              341300        NEAR BAY
# 4         565         259         3.8462              342200        NEAR BAY

# %%
data.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
#        population  households  median_income  median_house_value  \
# 20635         845         330         1.5603               78100
# 20636         356         114         2.5568               77100
# 20637        1007         433         1.7000               92300
# 20638         741         349         1.8672               84700
# 20639        1387         530         2.3886               89400
#
#       ocean_proximity
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  int64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# #### Q.1. What is the average median income of the data set and check the distribution of data using appropriate plots. Please explain the distribution of the plot.

# %%
# Calculating the average median income
average_median_income = np.mean(data['median_income'])

print("Average Median Income:", average_median_income)
# Out:
# Average Median Income: 3.8706710029069766

# %%
# Creating a histogram to visualize the distribution of median income
plt.figure(figsize=(10, 6))
plt.hist(data['median_income'], bins=30, color='blue', edgecolor='black')
plt.xlabel('Median Income')
plt.ylabel('Frequency')
plt.title('Distribution of Median Income')
plt.grid(True)
plt.show()

# %% [markdown]
# ##### observation-->the histogram is tilted towars left indicate lower median income group

# %% [markdown]
# #### Q 2.Draw an appropriate plot to see the distribution of housing_median_age and explain your observations.

# %%
# this will set a style to histogram - whitegrid is built in style
sns.set(style='whitegrid')

# Creating a histogram plot for housing_median_age
plt.figure(figsize=(10, 5))
sns.histplot(data['housing_median_age'], bins=50, kde=True, color='green')

# Adding labels and title
plt.xlabel('Housing Median Age')
plt.ylabel('Frequency')
plt.title('Distribution of Housing Median Age')

plt.show()

# %% [markdown]
# #### Observation -->
# histogram has 4 peaks suggesting that  housing median age contains distinct clusters of housing properties at specific age ranges, and a significant proportion of properties are relatively older

# %% [markdown]
# #### Q3. Show with the help of visualization, how median_income and median_house_values are related?

# %%
# Created a scatter plot for median_income vs median_house_value
plt.figure(figsize=(10, 6))
plt.scatter(data['median_income'], data['median_house_value'], alpha=.5, color='red')

# Adding labels and title
plt.xlabel('Median Income')
plt.ylabel('Median House Value')
plt.title('Median Income vs Median House Value')

plt.show()

# %% [markdown]
# #### Q4. Create a data set by deleting the corresponding examples from the data set for which total_bedrooms are not available.

# %%
# Created a new dataset by dropping rows with missing values in the 'total_bedrooms' column
data_without_missing_bedrooms = data.dropna(subset=['total_bedrooms'])

#  reset the index of the new DataFrame
data_without_missing_bedrooms.reset_index(drop=True, inplace=True)

#  the new dataset without missing 'total_bedrooms'
print(data_without_missing_bedrooms)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20428    -121.09     39.48                  25         1665           374.0
# 20429    -121.21     39.49                  18          697           150.0
# 20430    -121.22     39.43                  17         2254           485.0
# 20431    -121.32     39.43                  18         1860           409.0
# 20432    -121.24     39.37                  16         2785           616.0
#
# ...

# %% [markdown]
# #### Q5. Create a data set by filling the missing data with the mean value of the total_bedrooms in the original data set.

# %%
# Calculated the mean value of 'total_bedrooms' from the original dataset
mean_total_bedrooms = data['total_bedrooms'].mean()

# Created a new dataset with missing 'total_bedrooms' filled with the mean value
data_filled_with_mean = data.fillna({'total_bedrooms': mean_total_bedrooms})

# the new dataset with missing 'total_bedrooms' filled
print(data_filled_with_mean)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %% [markdown]
# #### Q6. Write a programming construct (create a user defined function) to calculate the median value of the data set wherever required.

# %%
def calculate_median(data):
    
    #  sorting in ascending order
    sorted_data = sorted(data)
    
    n = len(sorted_data)
    if n % 2 == 1:
        # If the number of data points is odd, return the middle value
        median_index = n // 2
        median = sorted_data[median_index]
    else:
        # If the number of data points is even, return the average of the two middle values
        right_middle_index = n // 2
        left_middle_index = right_middle_index - 1
        median = (sorted_data[left_middle_index] + sorted_data[right_middle_index]) / 2
        
    return median

# %% [markdown]
# ##### now we can calculate median value of any column - just put the column name in the place of 'total_bedrooms'

# %%
column_name = 'total_bedrooms'
column_data = data[column_name]

# Calling the function to calculate the median
median_value = calculate_median(column_data)

# Output the result
print("Median of column '{}': {}".format(column_name, median_value))
# Out:
# Median of column 'total_bedrooms': 322.5

# %% [markdown]
# #### Q7. Plot latitude versus longitude and explain your observations.

# %%
# Create a scatter plot for latitude vs longitude
plt.figure(figsize=(10, 6))
plt.scatter(data['longitude'], data['latitude'], alpha=0.5, color='blue')

# Add labels and title
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Latitude vs Longitude')

plt.show()

# %% [markdown]
# #### Q8. Create a data set for which the ocean_proximity is ‘Near ocean’.

# %%
# creating data set fro ocean proximity= near ocean
near_ocean_data = data.loc[data['ocean_proximity'] == 'NEAR OCEAN'].copy()

# %%
print(near_ocean_data)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1850     -124.17     41.80                  16         2739           480.0
# 1851     -124.30     41.80                  19         2672           552.0
# 1852     -124.23     41.75                  11         3159           616.0
# 1853     -124.21     41.77                  17         3461           722.0
# 1854     -124.19     41.78                  15         3140           714.0
# ...          ...       ...                 ...          ...             ...
# 20380    -118.83     34.14                  16         1316           194.0
# 20381    -118.83     34.14                  16         1956           312.0
# 20423    -119.00     34.08                  17         1822           438.0
# 20424    -118.75     34.18                   4        16704          2704.0
# 20425    -118.75     34.17                  18         6217           858.0
#
# ...

# %% [markdown]
# #### Q9. Find the mean and median of the median income for the data set created in question 8.

# %%
# Created a new dataset containing only rows where 'ocean_proximity' is 'Near ocean'
data_near_ocean = data[data['ocean_proximity'] == 'NEAR OCEAN']

# Calculating the mean and median of the 'median_income' column in the 'data_near_ocean' DataFrame
mean_median_income = data_near_ocean['median_income'].mean()
median_median_income = data_near_ocean['median_income'].median()

print("Mean of Median Income:", mean_median_income)
print("Median of Median Income:", median_median_income)
# Out:
# Mean of Median Income: 4.0057848006019565
# Median of Median Income: 3.64705

# %% [markdown]
# #### Q10. Please create a new column named total_bedroom_size. If the total bedrooms is 10 or less, it should be quoted as small. If the total bedrooms is 11 or more but less than 1000, it should be medium, otherwise it should be considered large.

# %%
# function to categorize the total bedrooms size
def categorize_bedroom_size(total_bedrooms):
    if total_bedrooms <= 10:
        return 'small'
    elif total_bedrooms >= 11 and total_bedrooms < 1000:
        return 'medium'
    else:
        return 'large'

#  created the 'total_bedroom_size' column
data['total_bedroom_size'] = data['total_bedrooms'].apply(categorize_bedroom_size)

# Display of DataFrame with the new 'total_bedroom_size' column
print(data)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...
